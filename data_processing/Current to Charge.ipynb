# %%
# made by Gibeom LEE, HI LAB
# 1. 우선 offset 된 데이터를 baseline correction 해줍니다. (앞 뒤 n % 기준으로)
# 2. Peak를 검출하고, 시간대를 나타내줍니다.
# 3. 수동을 일정 부분을 잘라서 적분해줍니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import cumulative_trapezoid
import os
from scipy.signal import find_peaks

# %%
# 사용자 변경
file_path = r"C:\Users\user\Documents\카카오톡 받은 파일\새 폴더\8_cycle.csv"

# 얼마나 앞뒤 비율 사용할 것인지 (%) ===
fraction_percent = 0 # 앞뒤 몇 %를 baseline 추정에 사용할지 조정 ####여기에서 오차 발생이 생길 수 있음.

# *ex) (10) = 10 μA/V 기준  %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 
Current_scale = 200

# %%
df = pd.read_csv(file_path, header=None, skiprows=30)

df.columns = ['Time', 'Current']
# 데이터 형식 변환...글자 -> NaN
df["Time"] = pd.to_numeric(df["Time"], errors='coerce')
df["Current"] = pd.to_numeric(df["Current"], errors='coerce')

# === 전류 시계열 추출 ===
current = df['Current'].values
n_total = len(current)
n_fraction = int(n_total * (fraction_percent / 100))

# === 앞쪽과 뒤쪽 데이터로 baseline 계산 === ###여기서도 잘 조절해봐.
front_section = current[:n_fraction]
back_section = current[-n_fraction:]
baseline_offset = np.mean(np.concatenate([front_section, back_section]))
#baseline_offset = np.mean(np.concatenate([ back_section]))
baseline_offset = 0.0 if np.isnan(baseline_offset) else baseline_offset
print(f"Offset: {baseline_offset:4f}")

# === offset 제거 ===
Cor_current = current - baseline_offset
df['Cor_current'] = Cor_current


print(f"I_max: {df.iloc[:, 1].max(skipna=True):.6f} μA")
print(f"I_min: {df.iloc[:, 1].min(skipna=True):.6f} μA")
print(f"I_pp: {df.iloc[:, 1].max(skipna=True)-df.iloc[:, 1].min(skipna=True):.6f} μA")

# === 결과 시각화 ===
plt.figure(figsize=(10, 5))
plt.plot(df['Time'], df['Current'], label='Original', alpha=0.5)
plt.plot(df['Time'], df['Cor_current'], label=f'Offset Removed ({fraction_percent}% head+tail)', linewidth=1.2)
plt.axhline(0, color='gray', linestyle='--')
plt.xlabel("Time (s)")
plt.ylabel("unconverted voltage (V)")
plt.title("Offset Correction")
plt.legend()
plt.grid(True)
plt.tight_layout()
#plt.ylim(-16,3)
plt.show()

df["Current"] = df["Cor_current"]


print(f"{Current_scale} μA/V is considered")
df["Current"] = df["Current"]*(Current_scale)
# Out:
# Offset: -0.003798
# I_max: 3.710630 μA
# I_min: -3.360630 μA
# I_pp: 7.071260 μA
# 200 μA/V is considered

# %%
peaks, properties = find_peaks(df["Current"], height=2.8, distance=1000, prominence=2)  # Find peak & print time

print(" ")
print("Detected peaks at:")
for idx in peaks:
    print(f"Time: {df['Time'].iloc[idx]:.5f} s, Current: {df['Current'].iloc[idx]:.3f} μA")
    
plt.figure(figsize=(10, 5))
plt.plot(df.iloc[:, 0], df.iloc[:, 1], label="AC current", color='b')
plt.plot(df["Time"].iloc[peaks], df["Current"].iloc[peaks], "ro", label='Detected Peaks')
plt.xlabel("Time (s)")
#plt.ylabel("Current (μA)")
#plt.title("Original current & peak")
#plt.ylim(-60,60)
plt.grid(True)
plt.show()
# Out:
#
# Detected peaks at:
# Time: 0.00025 s, Current: 23.697 μA
# Time: 0.00131 s, Current: 9.697 μA
# Time: 0.00231 s, Current: 213.322 μA
# Time: 0.00371 s, Current: 213.448 μA
# Time: 0.00493 s, Current: 437.198 μA
# Time: 0.00628 s, Current: 285.948 μA
# Time: 0.00728 s, Current: 198.010 μA
# Time: 0.00858 s, Current: 312.448 μA
# Time: 0.00972 s, Current: 59.135 μA
# Time: 0.01078 s, Current: 462.384 μA
# Time: 0.01215 s, Current: 163.697 μA
# Time: 0.01352 s, Current: 464.886 μA
# Time: 0.01508 s, Current: 102.822 μA
# Time: 0.01615 s, Current: 5.822 μA
# Time: 0.01727 s, Current: 12.947 μA
# Time: 0.01931 s, Current: 19.322 μA
# Time: 0.02071 s, Current: 24.135 μA
# Time: 0.02192 s, Current: 6.260 μA
# Time: 0.02336 s, Current: 4.010 μA
# Time: 0.02481 s, Current: 22.885 μA
# Time: 0.02593 s, Current: 21.510 μA
# Time: 0.02693 s, Current: 4.947 μA
# Time: 0.02806 s, Current: 18.760 μA
# Time: 0.02913 s, Current: 23.135 μA
# Time: 0.03016 s, Current: 10.697 μA
# Time: 0.03183 s, Current: 13.947 μA
# Time: 0.03288 s, Current: 446.636 μA
# Time: 0.03426 s, Current: 313.698 μA
# Time: 0.03577 s, Current: 402.572 μA
# Time: 0.03721 s, Current: 359.886 μA
# Time: 0.03836 s, Current: 67.010 μA
# Time: 0.03958 s, Current: 187.635 μA
# Time: 0.04096 s, Current: 261.198 μA
# Time: 0.04213 s, Current: 364.572 μA
# Time: 0.04350 s, Current: 534.198 μA
# Time: 0.04463 s, Current: 82.322 μA
# Time: 0.04630 s, Current: 103.822 μA
# Time: 0.04838 s, Current: 5.447 μA
# Time: 0.05038 s, Current: 14.072 μA
# Time: 0.05158 s, Current: 11.947 μA
# Time: 0.05273 s, Current: 23.197 μA
# Time: 0.05404 s, Current: 17.322 μA
# Time: 0.05604 s, Current: 7.697 μA
# Time: 0.05704 s, Current: 5.947 μA
# Time: 0.05833 s, Current: 17.322 μA
# Time: 0.05935 s, Current: 17.322 μA
# Time: 0.06038 s, Current: 11.510 μA
# Time: 0.06165 s, Current: 33.260 μA
# Time: 0.06307 s, Current: 542.384 μA
# Time: 0.06410 s, Current: 441.448 μA
# Time: 0.06532 s, Current: 314.010 μA
# Time: 0.06657 s, Current: 416.448 μA
# Time: 0.06769 s, Current: 60.197 μA
# Time: 0.06882 s, Current: 262.698 μA
# Time: 0.07055 s, Current: 243.572 μA
# Time: 0.07176 s, Current: 431.010 μA
# Time: 0.07307 s, Current: 304.134 μA
# Time: 0.07407 s, Current: 151.260 μA
# Time: 0.07536 s, Current: 68.072 μA
# Time: 0.07695 s, Current: 14.572 μA
# Time: 0.07881 s, Current: 23.947 μA
# Time: 0.08096 s, Current: 5.260 μA
# Time: 0.08289 s, Current: 12.135 μA
# Time: 0.08431 s, Current: 12.447 μA
# Time: 0.08540 s, Current: 10.635 μA
# Time: 0.08666 s, Current: 23.197 μA
# Time: 0.08769 s, Current: 13.072 μA
# Time: 0.08936 s, Current: 9.322 μA
# Time: 0.09086 s, Current: 11.447 μA
# Time: 0.09196 s, Current: 27.385 μA
# Time: 0.09330 s, Current: 521.198 μA
# Time: 0.09469 s, Current: 331.760 μA
# Time: 0.09620 s, Current: 279.448 μA
# Time: 0.09728 s, Current: 409.136 μA
# Time: 0.09906 s, Current: 173.197 μA
# Time: 0.10024 s, Current: 442.884 μA
# Time: 0.10200 s, Current: 296.822 μA
# Time: 0.10314 s, Current: 246.260 μA
# Time: 0.10459 s, Current: 71.947 μA
# Time: 0.10599 s, Current: 32.322 μA
# Time: 0.10727 s, Current: 6.072 μA
# Time: 0.10827 s, Current: 2.885 μA
# Time: 0.10935 s, Current: 16.510 μA
# Time: 0.11076 s, Current: 23.010 μA
# Time: 0.11266 s, Current: 21.510 μA
# Time: 0.11367 s, Current: 5.260 μA
# Time: 0.11467 s, Current: 7.135 μA
# Time: 0.11571 s, Current: 6.072 μA
# Time: 0.11671 s, Current: 14.072 μA
# Time: 0.11781 s, Current: 13.572 μA
# Time: 0.11938 s, Current: 16.010 μA
# Time: 0.12042 s, Current: 27.697 μA
# Time: 0.12187 s, Current: 11.947 μA
# Time: 0.12288 s, Current: 687.760 μA
# Time: 0.12389 s, Current: 69.510 μA
# Time: 0.12501 s, Current: 158.385 μA
# Time: 0.12606 s, Current: 400.134 μA
# Time: 0.12720 s, Current: 401.636 μA
# Time: 0.12828 s, Current: 83.447 μA
# Time: 0.12933 s, Current: 89.760 μA
# Time: 0.13071 s, Current: 441.010 μA
# Time: 0.13204 s, Current: 405.822 μA
# Time: 0.13329 s, Current: 229.886 μA
# Time: 0.13430 s, Current: 117.635 μA
# Time: 0.13543 s, Current: 155.010 μA
# Time: 0.13734 s, Current: 22.885 μA
# Time: 0.13932 s, Current: 7.885 μA
# Time: 0.14042 s, Current: 4.822 μA
# Time: 0.14159 s, Current: 8.760 μA
# Time: 0.14267 s, Current: 24.635 μA
# Time: 0.14369 s, Current: 10.010 μA
# Time: 0.14487 s, Current: 28.510 μA
# Time: 0.14599 s, Current: 17.697 μA
# Time: 0.14783 s, Current: 8.385 μA
# Time: 0.14942 s, Current: 16.510 μA
# Time: 0.15043 s, Current: 22.822 μA
# Time: 0.15163 s, Current: 17.135 μA
# Time: 0.15263 s, Current: 348.322 μA
# Time: 0.15386 s, Current: 492.760 μA
# Time: 0.15528 s, Current: 557.448 μA
# Time: 0.15665 s, Current: 434.760 μA
# Time: 0.15812 s, Current: 114.010 μA
# Time: 0.15969 s, Current: 298.322 μA
# Time: 0.16145 s, Current: 391.760 μA
# Time: 0.16302 s, Current: 243.698 μA
# Time: 0.16449 s, Current: 279.134 μA
# Time: 0.16607 s, Current: 132.260 μA
# Time: 0.16735 s, Current: 11.760 μA
# Time: 0.16925 s, Current: 10.697 μA
# Time: 0.17044 s, Current: 18.760 μA
# Time: 0.17210 s, Current: 7.697 μA
# Time: 0.17411 s, Current: 10.135 μA
# Time: 0.17519 s, Current: 24.322 μA
# Time: 0.17631 s, Current: 16.385 μA
# Time: 0.17804 s, Current: 14.260 μA
# Time: 0.17913 s, Current: 29.697 μA
# Time: 0.18024 s, Current: 10.135 μA
# Time: 0.18131 s, Current: 12.947 μA
# Time: 0.18233 s, Current: 53.885 μA
# Time: 0.18339 s, Current: 290.136 μA
# Time: 0.18462 s, Current: 426.636 μA
# Time: 0.18599 s, Current: 277.322 μA
# Time: 0.18742 s, Current: 66.447 μA
# Time: 0.18850 s, Current: 402.572 μA
# Time: 0.18968 s, Current: 56.510 μA
# Time: 0.19072 s, Current: 380.010 μA
# Time: 0.19204 s, Current: 314.572 μA
# Time: 0.19397 s, Current: 498.948 μA
# Time: 0.19532 s, Current: 65.260 μA
# Time: 0.19692 s, Current: 5.447 μA
# Time: 0.19945 s, Current: 5.010 μA
# Time: 0.20046 s, Current: 16.010 μA
# Time: 0.20166 s, Current: 9.697 μA
# Time: 0.20311 s, Current: 26.635 μA
# Time: 0.20434 s, Current: 20.260 μA
# Time: 0.20622 s, Current: 9.510 μA
# Time: 0.20753 s, Current: 11.510 μA
# Time: 0.20943 s, Current: 15.197 μA
# Time: 0.21046 s, Current: 9.697 μA
# Time: 0.21156 s, Current: 21.572 μA
# Time: 0.21274 s, Current: 196.197 μA
# Time: 0.21377 s, Current: 387.948 μA
# Time: 0.21485 s, Current: 244.010 μA
# Time: 0.21612 s, Current: 199.322 μA
# Time: 0.21785 s, Current: 70.322 μA
# Time: 0.21885 s, Current: 93.010 μA
# Time: 0.22068 s, Current: 463.510 μA
# Time: 0.22177 s, Current: 296.198 μA
# Time: 0.22302 s, Current: 485.698 μA
# Time: 0.22436 s, Current: 364.448 μA
# Time: 0.22538 s, Current: 48.322 μA
# Time: 0.22668 s, Current: 23.135 μA
# Time: 0.22777 s, Current: 15.010 μA
# Time: 0.22889 s, Current: 20.572 μA
# Time: 0.23097 s, Current: 6.072 μA
# Time: 0.23214 s, Current: 6.885 μA
# Time: 0.23347 s, Current: 11.822 μA
# Time: 0.23527 s, Current: 13.385 μA
# Time: 0.23679 s, Current: 22.010 μA
# Time: 0.23792 s, Current: 9.010 μA
# Time: 0.23987 s, Current: 12.010 μA
# Time: 0.24104 s, Current: 15.822 μA
# Time: 0.24224 s, Current: 24.635 μA
# Time: 0.24326 s, Current: 127.385 μA
# Time: 0.24509 s, Current: 252.510 μA
# Time: 0.24654 s, Current: 275.260 μA
# Time: 0.24829 s, Current: 340.698 μA
# Time: 0.24987 s, Current: 151.385 μA
# Time: 0.25122 s, Current: 404.384 μA
# Time: 0.25293 s, Current: 373.010 μA
# Time: 0.25460 s, Current: 230.198 μA
# Time: 0.25569 s, Current: 80.510 μA
# Time: 0.25735 s, Current: 6.947 μA
# Time: 0.25895 s, Current: 10.635 μA
# Time: 0.26125 s, Current: 19.322 μA
# Time: 0.26269 s, Current: 13.572 μA
# Time: 0.26438 s, Current: 12.260 μA
# Time: 0.26615 s, Current: 7.572 μA
# Time: 0.26729 s, Current: 17.135 μA
# Time: 0.26839 s, Current: 7.447 μA
# Time: 0.26939 s, Current: 17.822 μA
# Time: 0.27050 s, Current: 27.260 μA
# Time: 0.27156 s, Current: 12.260 μA
# Time: 0.27315 s, Current: 572.886 μA
# Time: 0.27501 s, Current: 220.822 μA
# Time: 0.27610 s, Current: 509.510 μA
# Time: 0.27753 s, Current: 147.447 μA
# Time: 0.27874 s, Current: 361.698 μA
# Time: 0.28074 s, Current: 298.822 μA
# Time: 0.28239 s, Current: 445.072 μA
# Time: 0.28404 s, Current: 409.948 μA
# Time: 0.28535 s, Current: 60.697 μA
# Time: 0.28670 s, Current: 16.822 μA
# Time: 0.28770 s, Current: 10.635 μA
# Time: 0.29051 s, Current: 3.197 μA
# Time: 0.29185 s, Current: 16.635 μA
# Time: 0.29305 s, Current: 19.260 μA
# Time: 0.29430 s, Current: 12.635 μA
# Time: 0.29535 s, Current: 28.510 μA
# Time: 0.29657 s, Current: 8.260 μA
# Time: 0.29801 s, Current: 7.697 μA
# Time: 0.29920 s, Current: 17.322 μA
# Time: 0.30051 s, Current: 27.572 μA
# Time: 0.30161 s, Current: 18.822 μA
# Time: 0.30300 s, Current: 742.886 μA
# Time: 0.30467 s, Current: 373.698 μA
# Time: 0.30592 s, Current: 451.886 μA
# Time: 0.30751 s, Current: 241.384 μA
# Time: 0.30894 s, Current: 81.822 μA
# Time: 0.30996 s, Current: 10.947 μA
# Time: 0.31098 s, Current: 384.886 μA
# Time: 0.31297 s, Current: 341.634 μA
# Time: 0.31413 s, Current: 243.072 μA
# Time: 0.31608 s, Current: 78.760 μA
# Time: 0.31732 s, Current: 9.322 μA
# Time: 0.31923 s, Current: 14.385 μA
# Time: 0.32052 s, Current: 16.635 μA
# Time: 0.32158 s, Current: 3.885 μA
# Time: 0.32282 s, Current: 5.260 μA
# Time: 0.32409 s, Current: 6.072 μA
# Time: 0.32517 s, Current: 24.947 μA
# Time: 0.32619 s, Current: 17.322 μA
# Time: 0.32742 s, Current: 18.260 μA
# Time: 0.32853 s, Current: 21.760 μA
# Time: 0.33012 s, Current: 10.385 μA
# Time: 0.33149 s, Current: 12.822 μA
# Time: 0.33251 s, Current: 452.510 μA
# Time: 0.33414 s, Current: 170.760 μA
# Time: 0.33533 s, Current: 455.260 μA
# Time: 0.33665 s, Current: 184.010 μA
# Time: 0.33830 s, Current: 182.635 μA
# Time: 0.33947 s, Current: 280.448 μA
# Time: 0.34053 s, Current: 38.010 μA
# Time: 0.34169 s, Current: 424.760 μA
# Time: 0.34323 s, Current: 337.448 μA
# Time: 0.34484 s, Current: 80.260 μA
# Time: 0.34607 s, Current: 42.635 μA
# Time: 0.34720 s, Current: 6.072 μA
# Time: 0.34953 s, Current: 3.822 μA
# Time: 0.35054 s, Current: 15.385 μA
# Time: 0.35213 s, Current: 13.135 μA
# Time: 0.35329 s, Current: 25.635 μA
# Time: 0.35444 s, Current: 13.885 μA
# Time: 0.35640 s, Current: 9.385 μA
# Time: 0.35814 s, Current: 7.260 μA
# Time: 0.35994 s, Current: 281.072 μA
# Time: 0.36111 s, Current: 75.135 μA
# Time: 0.36276 s, Current: 283.010 μA
# Time: 0.36411 s, Current: 387.698 μA
# Time: 0.36582 s, Current: 495.072 μA
# Time: 0.36747 s, Current: 225.636 μA
# Time: 0.36857 s, Current: 164.260 μA
# Time: 0.36962 s, Current: 92.072 μA
# Time: 0.37089 s, Current: 426.948 μA
# Time: 0.37212 s, Current: 48.572 μA
# Time: 0.37335 s, Current: 328.698 μA
# Time: 0.37440 s, Current: 29.322 μA
# Time: 0.37549 s, Current: 221.636 μA
# Time: 0.37661 s, Current: 6.260 μA
# Time: 0.37785 s, Current: 19.572 μA
# Time: 0.37891 s, Current: 13.947 μA
# Time: 0.38055 s, Current: 3.322 μA
# Time: 0.38162 s, Current: 4.322 μA
# Time: 0.38285 s, Current: 13.760 μA
# Time: 0.38444 s, Current: 21.697 μA
# Time: 0.38550 s, Current: 18.447 μA
# Time: 0.38687 s, Current: 23.197 μA
# Time: 0.38815 s, Current: 8.260 μA
# Time: 0.38915 s, Current: 4.010 μA
# Time: 0.39015 s, Current: 13.135 μA
# Time: 0.39180 s, Current: 78.760 μA
# Time: 0.39324 s, Current: 460.634 μA
# Time: 0.39482 s, Current: 373.572 μA
# Time: 0.39592 s, Current: 171.822 μA
# Time: 0.39737 s, Current: 222.260 μA
# Time: 0.39916 s, Current: 102.635 μA
# Time: 0.40049 s, Current: 68.072 μA
# Time: 0.40172 s, Current: 452.198 μA
# Time: 0.40352 s, Current: 305.136 μA
# Time: 0.40463 s, Current: 108.947 μA
# Time: 0.40648 s, Current: 57.947 μA
# Time: 0.40781 s, Current: 13.135 μA
# Time: 0.40913 s, Current: 16.322 μA
# Time: 0.41036 s, Current: 10.697 μA
# Time: 0.41143 s, Current: 25.135 μA
# Time: 0.41254 s, Current: 15.197 μA
# Time: 0.41445 s, Current: 15.010 μA
# Time: 0.41643 s, Current: 12.135 μA
# Time: 0.41747 s, Current: 20.572 μA
# Time: 0.41932 s, Current: 20.572 μA
# Time: 0.42058 s, Current: 29.697 μA
# Time: 0.42189 s, Current: 15.197 μA
# Time: 0.42325 s, Current: 436.134 μA
# Time: 0.42436 s, Current: 146.072 μA
# Time: 0.42589 s, Current: 348.636 μA
# Time: 0.42704 s, Current: 49.697 μA
# Time: 0.42807 s, Current: 316.698 μA
# Time: 0.42928 s, Current: 90.135 μA
# Time: 0.43054 s, Current: 322.322 μA
# Time: 0.43206 s, Current: 333.572 μA
# Time: 0.43329 s, Current: 233.134 μA
# Time: 0.43445 s, Current: 316.948 μA
# Time: 0.43589 s, Current: 65.635 μA
# Time: 0.43734 s, Current: 23.197 μA
# Time: 0.43835 s, Current: 4.010 μA
# Time: 0.43947 s, Current: 12.760 μA
# Time: 0.44105 s, Current: 16.510 μA
# Time: 0.44235 s, Current: 21.260 μA
# Time: 0.44353 s, Current: 28.697 μA
# Time: 0.44543 s, Current: 31.447 μA
# Time: 0.44655 s, Current: 14.572 μA
# Time: 0.44838 s, Current: 12.760 μA
# Time: 0.44949 s, Current: 21.760 μA
# Time: 0.45059 s, Current: 30.135 μA
# Time: 0.45199 s, Current: 79.385 μA
# Time: 0.45338 s, Current: 383.572 μA
# Time: 0.45512 s, Current: 210.822 μA
# Time: 0.45634 s, Current: 138.697 μA
# Time: 0.45820 s, Current: 150.135 μA
# Time: 0.45950 s, Current: 200.948 μA
# Time: 0.46075 s, Current: 404.384 μA
# Time: 0.46210 s, Current: 376.260 μA
# Time: 0.46362 s, Current: 319.448 μA
# Time: 0.46479 s, Current: 174.322 μA
# Time: 0.46601 s, Current: 50.635 μA
# Time: 0.46780 s, Current: 19.072 μA
# Time: 0.46949 s, Current: 28.510 μA
# Time: 0.47050 s, Current: 18.947 μA
# Time: 0.47156 s, Current: 8.197 μA
# Time: 0.47257 s, Current: 11.760 μA
# Time: 0.47417 s, Current: 13.947 μA
# Time: 0.47555 s, Current: 30.697 μA
# Time: 0.47725 s, Current: 19.260 μA
# Time: 0.47882 s, Current: 30.697 μA
# Time: 0.48000 s, Current: 8.885 μA
# Time: 0.48107 s, Current: 49.322 μA
# Time: 0.48242 s, Current: 65.260 μA
# Time: 0.48350 s, Current: 313.760 μA
# Time: 0.48544 s, Current: 395.136 μA
# Time: 0.48675 s, Current: 382.822 μA
# Time: 0.48777 s, Current: 108.510 μA
# Time: 0.48947 s, Current: 255.198 μA
# Time: 0.49071 s, Current: 487.072 μA
# Time: 0.49241 s, Current: 250.072 μA
# Time: 0.49346 s, Current: 9.197 μA
# Time: 0.49447 s, Current: 255.760 μA
# Time: 0.49583 s, Current: 188.947 μA
# Time: 0.49698 s, Current: 8.197 μA
# Time: 0.49811 s, Current: 6.947 μA
# Time: 0.49950 s, Current: 17.510 μA
# Time: 0.50062 s, Current: 15.010 μA
# Time: 0.50231 s, Current: 13.385 μA
# Time: 0.50357 s, Current: 28.385 μA
# Time: 0.50531 s, Current: 9.572 μA
# Time: 0.50658 s, Current: 11.760 μA
# Time: 0.50766 s, Current: 12.635 μA
# Time: 0.50927 s, Current: 17.010 μA
# Time: 0.51042 s, Current: 16.197 μA
# Time: 0.51148 s, Current: 73.572 μA
# Time: 0.51269 s, Current: 91.572 μA
# Time: 0.51371 s, Current: 371.260 μA
# Time: 0.51519 s, Current: 411.886 μA
# Time: 0.51630 s, Current: 138.072 μA
# Time: 0.51761 s, Current: 390.072 μA
# Time: 0.51889 s, Current: 128.197 μA
# Time: 0.51992 s, Current: 101.510 μA
# Time: 0.52120 s, Current: 267.072 μA
# Time: 0.52240 s, Current: 145.697 μA
# Time: 0.52408 s, Current: 392.572 μA
# Time: 0.52562 s, Current: 133.635 μA
# Time: 0.52679 s, Current: 8.072 μA
# Time: 0.52788 s, Current: 23.197 μA
# Time: 0.52889 s, Current: 10.135 μA
# Time: 0.53129 s, Current: 6.260 μA
# Time: 0.53233 s, Current: 5.322 μA
# Time: 0.53333 s, Current: 15.072 μA
# Time: 0.53452 s, Current: 16.385 μA
# Time: 0.53558 s, Current: 23.010 μA
# Time: 0.53670 s, Current: 23.510 μA
# Time: 0.53853 s, Current: 8.260 μA
# Time: 0.54013 s, Current: 8.510 μA
# Time: 0.54120 s, Current: 14.572 μA
# Time: 0.54234 s, Current: 25.322 μA
# Time: 0.54348 s, Current: 312.072 μA
# Time: 0.54468 s, Current: 251.322 μA
# Time: 0.54607 s, Current: 286.260 μA
# Time: 0.54732 s, Current: 116.760 μA
# Time: 0.54841 s, Current: 293.136 μA
# Time: 0.55005 s, Current: 104.260 μA
# Time: 0.55139 s, Current: 471.072 μA
# Time: 0.55285 s, Current: 335.510 μA
# Time: 0.55388 s, Current: 280.760 μA
# Time: 0.55548 s, Current: 59.260 μA
# Time: 0.55655 s, Current: 19.760 μA
# Time: 0.55799 s, Current: 14.697 μA
# Time: 0.55911 s, Current: 10.135 μA
# Time: 0.56029 s, Current: 11.822 μA
# Time: 0.56136 s, Current: 22.510 μA
# Time: 0.56262 s, Current: 14.760 μA
# Time: 0.56453 s, Current: 10.635 μA
# Time: 0.56565 s, Current: 10.697 μA
# Time: 0.56765 s, Current: 16.197 μA
# Time: 0.56940 s, Current: 20.885 μA
# Time: 0.57071 s, Current: 29.510 μA
# Time: 0.57240 s, Current: 83.760 μA
# Time: 0.57349 s, Current: 463.886 μA
# Time: 0.57492 s, Current: 359.072 μA
# Time: 0.57608 s, Current: 415.572 μA
# Time: 0.57757 s, Current: 388.948 μA
# Time: 0.57920 s, Current: 140.635 μA
# Time: 0.58117 s, Current: 522.386 μA
# Time: 0.58253 s, Current: 316.136 μA
# Time: 0.58359 s, Current: 355.136 μA
# Time: 0.58543 s, Current: 67.385 μA
# Time: 0.58652 s, Current: 14.760 μA
# Time: 0.58752 s, Current: 8.885 μA
# Time: 0.58933 s, Current: 2.822 μA
# Time: 0.59113 s, Current: 14.385 μA
# Time: 0.59233 s, Current: 12.010 μA
# Time: 0.59351 s, Current: 19.885 μA
# Time: 0.59455 s, Current: 23.697 μA
# Time: 0.59561 s, Current: 20.572 μA
# Time: 0.59703 s, Current: 8.510 μA
# Time: 0.59847 s, Current: 7.260 μA
# Time: 0.59947 s, Current: 14.447 μA
# Time: 0.60052 s, Current: 410.136 μA
# Time: 0.60157 s, Current: 61.697 μA
# Time: 0.60265 s, Current: 85.572 μA
# Time: 0.60368 s, Current: 326.448 μA
# Time: 0.60562 s, Current: 323.636 μA
# Time: 0.60662 s, Current: 423.386 μA
# Time: 0.60795 s, Current: 307.698 μA
# Time: 0.60972 s, Current: 184.822 μA
# Time: 0.61082 s, Current: 211.636 μA
# Time: 0.61266 s, Current: 224.698 μA
# Time: 0.61370 s, Current: 352.260 μA
# Time: 0.61545 s, Current: 103.135 μA
# Time: 0.61678 s, Current: 22.072 μA
# Time: 0.61788 s, Current: 18.135 μA
# Time: 0.61957 s, Current: 32.260 μA
# Time: 0.62058 s, Current: 19.135 μA
# Time: 0.62164 s, Current: 7.697 μA
# Time: 0.62265 s, Current: 11.822 μA
# Time: 0.62415 s, Current: 17.447 μA
# Time: 0.62563 s, Current: 26.760 μA
# Time: 0.62705 s, Current: 23.135 μA
# Time: 0.62890 s, Current: 26.135 μA
# Time: 0.63069 s, Current: 14.572 μA
# Time: 0.63205 s, Current: 16.010 μA
# Time: 0.63325 s, Current: 250.886 μA
# Time: 0.63467 s, Current: 578.636 μA
# Time: 0.63596 s, Current: 483.260 μA
# Time: 0.63703 s, Current: 207.260 μA
# Time: 0.63812 s, Current: 29.697 μA
# Time: 0.63915 s, Current: 239.634 μA
# Time: 0.64105 s, Current: 497.322 μA
# Time: 0.64206 s, Current: 418.822 μA
# Time: 0.64319 s, Current: 378.386 μA
# Time: 0.64456 s, Current: 326.198 μA
# Time: 0.64568 s, Current: 61.010 μA
# Time: 0.64686 s, Current: 5.260 μA
# Time: 0.64799 s, Current: 3.510 μA
# Time: 0.64958 s, Current: 18.135 μA
# Time: 0.65059 s, Current: 15.510 μA
# Time: 0.65199 s, Current: 14.197 μA
# Time: 0.65365 s, Current: 20.072 μA
# Time: 0.65467 s, Current: 7.260 μA
# Time: 0.65626 s, Current: 9.197 μA
# Time: 0.65726 s, Current: 14.885 μA
# Time: 0.65835 s, Current: 9.010 μA
# Time: 0.65955 s, Current: 17.635 μA
# Time: 0.66075 s, Current: 30.010 μA
# Time: 0.66242 s, Current: 390.760 μA
# Time: 0.66342 s, Current: 4.635 μA
# Time: 0.66442 s, Current: 213.822 μA
# Time: 0.66581 s, Current: 348.698 μA
# Time: 0.66778 s, Current: 383.886 μA
# Time: 0.66879 s, Current: 57.635 μA
# Time: 0.66984 s, Current: 282.010 μA
# Time: 0.67132 s, Current: 294.572 μA
# Time: 0.67237 s, Current: 79.885 μA
# Time: 0.67354 s, Current: 227.072 μA
# Time: 0.67457 s, Current: 227.948 μA
# Time: 0.67576 s, Current: 26.447 μA
# Time: 0.67691 s, Current: 10.697 μA
# Time: 0.67796 s, Current: 23.697 μA
# Time: 0.67917 s, Current: 5.760 μA
# Time: 0.68137 s, Current: 6.885 μA
# Time: 0.68341 s, Current: 14.260 μA
# Time: 0.68441 s, Current: 8.885 μA
# Time: 0.68551 s, Current: 17.947 μA
# Time: 0.68688 s, Current: 22.322 μA
# Time: 0.68872 s, Current: 8.510 μA
# Time: 0.68973 s, Current: 3.322 μA
# Time: 0.69077 s, Current: 16.197 μA
# Time: 0.69259 s, Current: 73.260 μA
# Time: 0.69369 s, Current: 490.386 μA
# Time: 0.69526 s, Current: 307.198 μA
# Time: 0.69671 s, Current: 452.948 μA
# Time: 0.69841 s, Current: 284.322 μA
# Time: 0.69943 s, Current: 71.135 μA
# Time: 0.70076 s, Current: 459.448 μA
# Time: 0.70182 s, Current: 206.948 μA
# Time: 0.70342 s, Current: 387.384 μA
# Time: 0.70453 s, Current: 122.010 μA
# Time: 0.70562 s, Current: 47.072 μA
# Time: 0.70687 s, Current: 5.510 μA
# Time: 0.70807 s, Current: 21.072 μA
# Time: 0.70919 s, Current: 7.447 μA
# Time: 0.71027 s, Current: 19.322 μA
# Time: 0.71179 s, Current: 19.072 μA
# Time: 0.71363 s, Current: 4.947 μA
# Time: 0.71563 s, Current: 10.197 μA
# Time: 0.71673 s, Current: 11.447 μA
# Time: 0.71773 s, Current: 13.947 μA
# Time: 0.71925 s, Current: 19.572 μA
# Time: 0.72028 s, Current: 6.447 μA
# Time: 0.72130 s, Current: 85.072 μA
# Time: 0.72235 s, Current: 48.885 μA
# Time: 0.72354 s, Current: 225.198 μA
# Time: 0.72529 s, Current: 320.698 μA
# Time: 0.72684 s, Current: 83.447 μA
# Time: 0.72861 s, Current: 221.072 μA
# Time: 0.73074 s, Current: 271.134 μA
# Time: 0.73201 s, Current: 153.322 μA
# Time: 0.73362 s, Current: 412.572 μA
# Time: 0.73495 s, Current: 107.072 μA
# Time: 0.73674 s, Current: 32.947 μA
# Time: 0.73804 s, Current: 11.447 μA
# Time: 0.73971 s, Current: 11.322 μA
# Time: 0.74141 s, Current: 22.385 μA
# Time: 0.74271 s, Current: 22.072 μA
# Time: 0.74476 s, Current: 27.260 μA
# Time: 0.74621 s, Current: 13.885 μA
# Time: 0.74751 s, Current: 12.822 μA
# Time: 0.74855 s, Current: 8.385 μA
# Time: 0.74965 s, Current: 21.197 μA
# Time: 0.75075 s, Current: 27.697 μA
# Time: 0.75176 s, Current: 202.134 μA
# Time: 0.75290 s, Current: 245.448 μA
# Time: 0.75401 s, Current: 75.947 μA
# Time: 0.75513 s, Current: 315.636 μA
# Time: 0.75695 s, Current: 398.572 μA
# Time: 0.75873 s, Current: 135.510 μA
# Time: 0.76005 s, Current: 112.697 μA
# Time: 0.76111 s, Current: 96.635 μA
# Time: 0.76232 s, Current: 332.948 μA
# Time: 0.76376 s, Current: 362.448 μA
# Time: 0.76536 s, Current: 160.447 μA
# Time: 0.76696 s, Current: 24.635 μA
# Time: 0.76856 s, Current: 26.072 μA
# Time: 0.76965 s, Current: 37.947 μA
# Time: 0.77066 s, Current: 25.635 μA
# Time: 0.77172 s, Current: 13.635 μA
# Time: 0.77273 s, Current: 15.072 μA
# Time: 0.77441 s, Current: 39.947 μA
# Time: 0.77633 s, Current: 21.260 μA
# Time: 0.77768 s, Current: 31.322 μA
# Time: 0.77877 s, Current: 25.322 μA
# Time: 0.77983 s, Current: 11.635 μA
# Time: 0.78138 s, Current: 146.697 μA
# Time: 0.78271 s, Current: 338.948 μA
# Time: 0.78422 s, Current: 271.010 μA
# Time: 0.78594 s, Current: 479.760 μA
# Time: 0.78772 s, Current: 445.636 μA
# Time: 0.78890 s, Current: 57.322 μA
# Time: 0.79026 s, Current: 410.572 μA
# Time: 0.79161 s, Current: 257.136 μA
# Time: 0.79297 s, Current: 384.698 μA
# Time: 0.79398 s, Current: 324.760 μA
# Time: 0.79503 s, Current: 236.510 μA
# Time: 0.79644 s, Current: 9.822 μA
# Time: 0.79807 s, Current: 9.572 μA
# Time: 0.79967 s, Current: 20.697 μA
# Time: 0.80067 s, Current: 18.822 μA
# Time: 0.80169 s, Current: 9.697 μA
# Time: 0.80274 s, Current: 21.385 μA
# Time: 0.80378 s, Current: 20.385 μA
# Time: 0.80485 s, Current: 8.260 μA
# Time: 0.80634 s, Current: 10.947 μA
# Time: 0.80744 s, Current: 18.947 μA
# Time: 0.80904 s, Current: 17.635 μA
# Time: 0.81038 s, Current: 19.135 μA
# Time: 0.81145 s, Current: 96.010 μA
# Time: 0.81286 s, Current: 381.634 μA
# Time: 0.81396 s, Current: 401.636 μA
# Time: 0.81554 s, Current: 431.510 μA
# Time: 0.81749 s, Current: 484.510 μA
# Time: 0.81908 s, Current: 148.322 μA
# Time: 0.82019 s, Current: 223.572 μA
# Time: 0.82136 s, Current: 83.635 μA
# Time: 0.82244 s, Current: 381.322 μA
# Time: 0.82365 s, Current: 135.947 μA
# Time: 0.82497 s, Current: 278.448 μA
# Time: 0.82685 s, Current: 13.947 μA
# Time: 0.82834 s, Current: 24.135 μA
# Time: 0.82968 s, Current: 6.572 μA
# Time: 0.83125 s, Current: 5.010 μA
# Time: 0.83239 s, Current: 13.385 μA
# Time: 0.83369 s, Current: 13.947 μA
# Time: 0.83479 s, Current: 5.510 μA
# Time: 0.83580 s, Current: 18.135 μA
# Time: 0.83696 s, Current: 20.260 μA
# Time: 0.83880 s, Current: 8.510 μA
# Time: 0.84085 s, Current: 17.322 μA
# Time: 0.84196 s, Current: 13.760 μA
# Time: 0.84302 s, Current: 132.510 μA
# Time: 0.84479 s, Current: 341.384 μA
# Time: 0.84649 s, Current: 459.010 μA
# Time: 0.84795 s, Current: 238.448 μA
# Time: 0.84896 s, Current: 6.885 μA
# Time: 0.84999 s, Current: 203.698 μA
# Time: 0.85113 s, Current: 305.948 μA
# Time: 0.85221 s, Current: 380.510 μA
# Time: 0.85333 s, Current: 427.448 μA
# Time: 0.85493 s, Current: 223.886 μA
# Time: 0.85613 s, Current: 53.447 μA
# Time: 0.85786 s, Current: 28.697 μA
# Time: 0.85907 s, Current: 7.447 μA
# Time: 0.86045 s, Current: 24.447 μA
# Time: 0.86192 s, Current: 20.385 μA
# Time: 0.86311 s, Current: 5.510 μA
# Time: 0.86478 s, Current: 8.510 μA
# Time: 0.86581 s, Current: 15.572 μA
# Time: 0.86691 s, Current: 15.197 μA
# Time: 0.86841 s, Current: 12.572 μA
# Time: 0.86943 s, Current: 28.385 μA
# Time: 0.87071 s, Current: 18.447 μA
# Time: 0.87263 s, Current: 348.010 μA
# Time: 0.87443 s, Current: 360.198 μA
# Time: 0.87570 s, Current: 557.010 μA
# Time: 0.87743 s, Current: 320.072 μA
# Time: 0.87850 s, Current: 61.010 μA
# Time: 0.87966 s, Current: 415.634 μA
# Time: 0.88092 s, Current: 440.322 μA
# Time: 0.88219 s, Current: 422.260 μA
# Time: 0.88332 s, Current: 15.885 μA
# Time: 0.88435 s, Current: 382.636 μA
# Time: 0.88549 s, Current: 47.572 μA
# Time: 0.88659 s, Current: 17.197 μA
# Time: 0.88832 s, Current: 4.947 μA
# Time: 0.89067 s, Current: 8.385 μA
# Time: 0.89169 s, Current: 16.697 μA
# Time: 0.89279 s, Current: 12.010 μA
# Time: 0.89383 s, Current: 9.572 μA
# Time: 0.89484 s, Current: 17.510 μA
# Time: 0.89649 s, Current: 7.135 μA
# Time: 0.89769 s, Current: 8.260 μA
# Time: 0.89964 s, Current: 15.822 μA
# Time: 0.90083 s, Current: 21.510 μA
# Time: 0.90223 s, Current: 24.447 μA
# Time: 0.90356 s, Current: 284.636 μA
# Time: 0.90476 s, Current: 246.010 μA
# Time: 0.90612 s, Current: 409.886 μA
# Time: 0.90728 s, Current: 387.510 μA
# Time: 0.90861 s, Current: 207.948 μA
# Time: 0.90975 s, Current: 83.447 μA
# Time: 0.91128 s, Current: 436.134 μA
# Time: 0.91300 s, Current: 193.947 μA
# Time: 0.91419 s, Current: 133.822 μA
# Time: 0.91560 s, Current: 92.885 μA
# Time: 0.91724 s, Current: 12.760 μA
# Time: 0.91864 s, Current: 17.822 μA
# Time: 0.91973 s, Current: 30.197 μA
# Time: 0.92079 s, Current: 11.010 μA
# Time: 0.92180 s, Current: 7.947 μA
# Time: 0.92281 s, Current: 5.822 μA
# Time: 0.92481 s, Current: 17.322 μA
# Time: 0.92631 s, Current: 12.572 μA
# Time: 0.92776 s, Current: 21.760 μA
# Time: 0.92885 s, Current: 18.322 μA
# Time: 0.93024 s, Current: 7.697 μA
# Time: 0.93176 s, Current: 82.010 μA
# Time: 0.93284 s, Current: 69.010 μA
# Time: 0.93431 s, Current: 493.572 μA
# Time: 0.93614 s, Current: 407.948 μA
# Time: 0.93800 s, Current: 340.072 μA
# Time: 0.93935 s, Current: 117.885 μA
# Time: 0.94095 s, Current: 340.572 μA
# Time: 0.94271 s, Current: 200.822 μA
# Time: 0.94388 s, Current: 384.386 μA
# Time: 0.94489 s, Current: 239.634 μA
# Time: 0.94639 s, Current: 34.197 μA
# Time: 0.94742 s, Current: 3.697 μA
# Time: 0.94845 s, Current: 7.135 μA
# Time: 0.94974 s, Current: 18.947 μA
# Time: 0.95075 s, Current: 18.260 μA
# Time: 0.95262 s, Current: 22.197 μA
# Time: 0.95386 s, Current: 16.822 μA
# Time: 0.95573 s, Current: 20.260 μA
# Time: 0.95762 s, Current: 18.322 μA
# Time: 0.95886 s, Current: 9.072 μA
# Time: 0.96016 s, Current: 58.322 μA
# Time: 0.96153 s, Current: 25.260 μA
# Time: 0.96293 s, Current: 358.886 μA
# Time: 0.96401 s, Current: 184.260 μA
# Time: 0.96552 s, Current: 431.198 μA
# Time: 0.96699 s, Current: 415.572 μA
# Time: 0.96833 s, Current: 320.510 μA
# Time: 0.97021 s, Current: 310.322 μA
# Time: 0.97185 s, Current: 415.572 μA
# Time: 0.97325 s, Current: 367.636 μA
# Time: 0.97430 s, Current: 159.822 μA
# Time: 0.97544 s, Current: 44.947 μA
# Time: 0.97702 s, Current: 15.010 μA
# Time: 0.97862 s, Current: 24.635 μA
# Time: 0.97976 s, Current: 6.635 μA
# Time: 0.98077 s, Current: 3.885 μA
# Time: 0.98229 s, Current: 13.072 μA
# Time: 0.98388 s, Current: 15.510 μA
# Time: 0.98588 s, Current: 19.635 μA
# Time: 0.98712 s, Current: 25.260 μA
# Time: 0.98837 s, Current: 6.072 μA
# Time: 0.98944 s, Current: 7.135 μA
# Time: 0.99093 s, Current: 14.197 μA
# Time: 0.99212 s, Current: 22.010 μA
# Time: 0.99314 s, Current: 442.072 μA
# Time: 0.99459 s, Current: 191.572 μA
# Time: 0.99635 s, Current: 551.822 μA
# Time: 0.99744 s, Current: 10.510 μA
# Time: 0.99845 s, Current: 188.072 μA
# Time: 0.99964 s, Current: 160.447 μA

# %%
# 2. 특정 범위 선택      
time_range = ( 0.0 , 6.0 ) ########################## MUST BE MODIFIED MANUALLY
df_filtered = df[(df.iloc[:, 0] >= time_range[0]) & (df.iloc[:, 0] <= time_range[1])]

# 양수/음수 분리
p_value = df_filtered[df_filtered["Current"] > 0]
n_value = df_filtered[df_filtered["Current"] < 0]
p_time = p_value["Time"].values
p_current = p_value["Current"].values
n_time = n_value["Time"].values
n_current = n_value["Current"].values

# 전하 적분 함수 정의 (1개 포인트도 대응)
def segment_and_integrate(current, time, df_full, threshold=0.01, scale_factor=1e3):
    if len(time) < 1:
        return 0.0
    total_charge = 0.0
    group_start = 0
    time_diffs = np.diff(time)
    for i, dt in enumerate(time_diffs):
        if dt > threshold:
            segment_t = time[group_start:i+1]
            segment_i = current[group_start:i+1]
            if len(segment_t) > 1:
                total_charge += scale_factor * cumulative_trapezoid(segment_i, segment_t, initial=0)[-1]
            elif len(segment_t) == 1:
                dt_est = 1e-6
                t0 = segment_t[0]
                if t0 in df_full["Time"].values:
                    idx = df_full.index[df_full["Time"] == t0].tolist()[0]
                    if 0 < idx < len(df_full) - 1:
                        dt_est = (df_full.iloc[idx + 1]["Time"] - df_full.iloc[idx - 1]["Time"]) / 2
                total_charge += scale_factor * segment_i[0] * dt_est
            group_start = i + 1
    if group_start < len(time):
        segment_t = time[group_start:]
        segment_i = current[group_start:]
        if len(segment_t) > 1:
            total_charge += scale_factor * cumulative_trapezoid(segment_i, segment_t, initial=0)[-1]
        elif len(segment_t) == 1:
            dt_est = 1e-6
            t0 = segment_t[0]
            if t0 in df_full["Time"].values:
                idx = df_full.index[df_full["Time"] == t0].tolist()[0]
                if 0 < idx < len(df_full) - 1:
                    dt_est = (df_full.iloc[idx + 1]["Time"] - df_full.iloc[idx - 1]["Time"]) / 2
            total_charge += scale_factor * segment_i[0] * dt_est
    return total_charge

# 적분 수행
p_charge = segment_and_integrate(p_current, p_time, df)
n_charge = segment_and_integrate(n_current, n_time, df)

print(f"양수 전하 값: {p_charge:.6f} nC")
print(f"음수 전하 값: {n_charge:.6f} nC")

plt.figure(figsize=(10, 5))
plt.plot(df_filtered.iloc[:, 0], df_filtered.iloc[:, 1], label="Current", color='g')
plt.xlabel("Time (s)")
#plt.ylabel("Current (μA)") ### 단위 고려 중요
#plt.title("Flat DEG Current / d=2cm")
#plt.ylim(-45, 5)
#plt.legend()
plt.grid(True)
plt.show()
# Out:
# 양수 전하 값: 4607.895291 nC
# 음수 전하 값: -5652.538773 nC

# %%
# ---- 아래 셀은 offset 바꿔가며 여러 번 실행해도 누적 안됨 ----
offset_value = 0.0 ########################## MUST BE MODIFIED MANUALLY

# 딱 한 번만 실행해서 '기준'을 저장
df_filtered_base = df_filtered.copy(deep=True)  # 원본 백업
current_adj = df_filtered_base["Current"] + offset_value

# 적분 (μA -> nC)
cumulative_charge = 1e3 * cumulative_trapezoid(current_adj.to_numpy(),
                                               df_filtered_base["Time"].to_numpy(),
                                               initial=0)

# 플롯
#print(f"{np.min(cumulative_charge):.3f} nC")
print(f"{np.min(cumulative_charge):.3f}")
plt.figure(figsize=(10, 5))
#plt.ylim(-0.37,0.02)
plt.plot(df_filtered_base["Time"], cumulative_charge, label="Cumulative Charge")
#plt.xlabel("Time (s)"); plt.ylabel("Collected Charge (nC)")
#plt.title("Flat DEG Charge / d=2cm");
plt.grid(True); plt.show()


# 8. 필터링된 데이터 저장
folder_path = os.path.dirname(file_path)
original_filename = os.path.basename(file_path)
filtered_file_name = f"Charge_{original_filename}"
filtered_file_path = os.path.join(folder_path, filtered_file_name)
#df_filtered.to_csv(filtered_file_path, index=False)

print(f"Filtered data saved at: {filtered_file_path}")
# Out:
# -133.581
# Filtered data saved at: C:\Users\user\Documents\카카오톡 받은 파일\새 폴더\Charge_8_cycle.csv
