# %%
# made by Gibeom LEE, HI LAB
# 1. 우선 offset 된 데이터를 baseline correction 해줍니다. (앞 뒤 n % 기준으로)
# 2. Peak를 검출하고, 시간대를 나타내줍니다.
# 3. 수동을 일정 부분을 잘라서 적분해줍니다.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import cumulative_trapezoid
import os
from scipy.signal import find_peaks

# %%
# 사용자 변경
file_path = r"C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\2. Normal Supercapacitor\240911_전압,전류 측정\240911_2 uA_long.csv"

# 얼마나 앞뒤 비율 사용할 것인지 (%) ===
fraction_percent = 0 # 앞뒤 몇 %를 baseline 추정에 사용할지 조정 ####여기에서 오차 발생이 생길 수 있음.

# *ex) (10) = 10 μA/V 기준  %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 중요 %%%%%%%%% 
Current_scale = 20

# %%
df = pd.read_csv(file_path, header=None, skiprows=30)

df.columns = ['Time', 'Current']
# 데이터 형식 변환...글자 -> NaN
df["Time"] = pd.to_numeric(df["Time"], errors='coerce')
df["Current"] = pd.to_numeric(df["Current"], errors='coerce')

# === 전류 시계열 추출 ===
current = df['Current'].values
n_total = len(current)
n_fraction = int(n_total * (fraction_percent / 100))

# === 앞쪽과 뒤쪽 데이터로 baseline 계산 === ###여기서도 잘 조절해봐.
if n_fraction == 0:
    baseline_offset = 0.0
else:
    front_section = current[:n_fraction]
    back_section = current[-n_fraction:]
    baseline_offset = np.mean(np.concatenate([front_section, back_section]))
    #baseline_offset = np.mean(np.concatenate([ back_section]))
    baseline_offset = 0.0 if np.isnan(baseline_offset) else baseline_offset
print(f"Offset: {baseline_offset:4f}")

# === offset 제거 ===
Cor_current = current - baseline_offset
df['Cor_current'] = Cor_current


print(f"I_max: {df.iloc[:, 1].max(skipna=True):.6f} μA")
print(f"I_min: {df.iloc[:, 1].min(skipna=True):.6f} μA")
print(f"I_pp: {df.iloc[:, 1].max(skipna=True)-df.iloc[:, 1].min(skipna=True):.6f} μA")

# === 결과 시각화 ===
plt.figure(figsize=(10, 5))
plt.plot(df['Time'], df['Current'], label='Original', alpha=0.5)
plt.plot(df['Time'], df['Cor_current'], label=f'Offset Removed ({fraction_percent}% head+tail)', linewidth=1.2)
plt.axhline(0, color='gray', linestyle='--')
plt.xlabel("Time (s)")
plt.ylabel("unconverted voltage (V)")
plt.title("Offset Correction")
plt.legend()
plt.grid(True)
plt.tight_layout()
#plt.ylim(-16,3)
plt.show()

df["Current"] = df["Cor_current"]


print(f"{Current_scale} μA/V is considered")
df["Current"] = df["Current"]*(Current_scale)
# Out:
# Offset: 0.000000
# I_max: 2.098750 μA
# I_min: 0.055000 μA
# I_pp: 2.043750 μA
# 20 μA/V is considered

# %%
peaks, properties = find_peaks(df["Current"], height=2.8, distance=1000, prominence=2)  # Find peak & print time

print(" ")
print("Detected peaks at:")
for idx in peaks:
    print(f"Time: {df['Time'].iloc[idx]:.5f} s, Current: {df['Current'].iloc[idx]:.3f} μA")
    
plt.figure(figsize=(10, 5))
plt.plot(df.iloc[:, 0], df.iloc[:, 1], label="AC current", color='b')
plt.plot(df["Time"].iloc[peaks], df["Current"].iloc[peaks], "ro", label='Detected Peaks')
plt.xlabel("Time (s)")
#plt.ylabel("Current (μA)")
#plt.title("Original current & peak")
#plt.ylim(-60,60)
plt.grid(True)
plt.show()
# Out:
#
# Detected peaks at:
# Time: 0.17760 s, Current: 35.725 μA
# Time: 0.61840 s, Current: 35.594 μA
# Time: 1.05880 s, Current: 35.600 μA
# Time: 1.72040 s, Current: 35.906 μA
# Time: 2.38120 s, Current: 41.975 μA
# Time: 3.04240 s, Current: 37.025 μA
# Time: 3.48320 s, Current: 35.844 μA
# Time: 3.92360 s, Current: 35.775 μA
# Time: 4.36440 s, Current: 35.813 μA
# Time: 4.80480 s, Current: 36.000 μA
# Time: 5.24560 s, Current: 36.088 μA
# Time: 5.90680 s, Current: 35.987 μA
# Time: 6.56760 s, Current: 36.144 μA
# Time: 7.00840 s, Current: 35.769 μA
# Time: 7.44920 s, Current: 35.794 μA
# Time: 7.88960 s, Current: 36.094 μA
# Time: 8.33080 s, Current: 36.044 μA
# Time: 8.77120 s, Current: 36.106 μA
# Time: 9.21200 s, Current: 36.088 μA
# Time: 9.87280 s, Current: 36.144 μA
# Time: 10.31360 s, Current: 35.888 μA
# Time: 10.75440 s, Current: 35.950 μA
# Time: 11.19520 s, Current: 36.006 μA
# Time: 11.63560 s, Current: 36.088 μA
# Time: 12.07640 s, Current: 36.100 μA
# Time: 12.73720 s, Current: 36.438 μA
# Time: 13.17800 s, Current: 41.769 μA
# Time: 13.61920 s, Current: 36.150 μA
# Time: 14.05960 s, Current: 36.094 μA
# Time: 14.50120 s, Current: 40.094 μA
# Time: 14.94120 s, Current: 36.063 μA
# Time: 15.38160 s, Current: 36.319 μA
# Time: 16.04240 s, Current: 40.069 μA
# Time: 16.70360 s, Current: 36.400 μA
# Time: 17.36440 s, Current: 38.194 μA
# Time: 17.80560 s, Current: 36.119 μA
# Time: 18.46680 s, Current: 36.281 μA
# Time: 19.12760 s, Current: 36.156 μA
# Time: 19.78880 s, Current: 36.194 μA
# Time: 20.22880 s, Current: 41.138 μA
# Time: 20.89040 s, Current: 36.413 μA
# Time: 21.33120 s, Current: 36.356 μA
# Time: 21.77200 s, Current: 36.206 μA
# Time: 22.21280 s, Current: 36.169 μA
# Time: 22.65320 s, Current: 36.581 μA
# Time: 23.31440 s, Current: 36.156 μA
# Time: 23.75520 s, Current: 36.313 μA
# Time: 24.19560 s, Current: 36.531 μA
# Time: 24.63640 s, Current: 36.444 μA
# Time: 25.07720 s, Current: 36.269 μA
# Time: 25.51800 s, Current: 36.431 μA
# Time: 25.95880 s, Current: 36.344 μA
# Time: 26.39880 s, Current: 38.663 μA
# Time: 27.06040 s, Current: 36.313 μA
# Time: 27.50120 s, Current: 36.388 μA
# Time: 27.94160 s, Current: 36.556 μA
# Time: 28.60280 s, Current: 36.388 μA
# Time: 29.04360 s, Current: 36.731 μA
# Time: 29.48440 s, Current: 39.744 μA
# Time: 29.92480 s, Current: 36.413 μA
# Time: 30.36560 s, Current: 36.469 μA
# Time: 30.80640 s, Current: 36.213 μA
# Time: 31.24720 s, Current: 36.513 μA
# Time: 31.90800 s, Current: 36.612 μA
# Time: 32.34880 s, Current: 36.344 μA
# Time: 32.78920 s, Current: 36.700 μA
# Time: 33.23120 s, Current: 41.006 μA
# Time: 33.67080 s, Current: 36.612 μA
# Time: 34.11160 s, Current: 36.519 μA
# Time: 34.55200 s, Current: 36.938 μA
# Time: 34.99320 s, Current: 37.988 μA
# Time: 35.65480 s, Current: 39.600 μA
# Time: 36.31520 s, Current: 36.519 μA
# Time: 36.97640 s, Current: 37.425 μA
# Time: 37.63760 s, Current: 37.125 μA
# Time: 38.07760 s, Current: 36.381 μA
# Time: 38.51880 s, Current: 36.600 μA
# Time: 38.95920 s, Current: 36.575 μA
# Time: 39.39960 s, Current: 38.369 μA
# Time: 39.84080 s, Current: 36.413 μA

# %%
# 2. 특정 범위 선택      
time_range = ( 0.0 , 6.0 ) ########################## MUST BE MODIFIED MANUALLY
df_filtered = df[(df.iloc[:, 0] >= time_range[0]) & (df.iloc[:, 0] <= time_range[1])]

# 양수/음수 분리
p_value = df_filtered[df_filtered["Current"] > 0]
n_value = df_filtered[df_filtered["Current"] < 0]
p_time = p_value["Time"].values
p_current = p_value["Current"].values
n_time = n_value["Time"].values
n_current = n_value["Current"].values

# 전하 적분 함수 정의 (1개 포인트도 대응)
def segment_and_integrate(current, time, df_full, threshold=0.01, scale_factor=1e3):
    if len(time) < 1:
        return 0.0
    total_charge = 0.0
    group_start = 0
    time_diffs = np.diff(time)
    for i, dt in enumerate(time_diffs):
        if dt > threshold:
            segment_t = time[group_start:i+1]
            segment_i = current[group_start:i+1]
            if len(segment_t) > 1:
                total_charge += scale_factor * cumulative_trapezoid(segment_i, segment_t, initial=0)[-1]
            elif len(segment_t) == 1:
                dt_est = 1e-6
                t0 = segment_t[0]
                if t0 in df_full["Time"].values:
                    idx = df_full.index[df_full["Time"] == t0].tolist()[0]
                    if 0 < idx < len(df_full) - 1:
                        dt_est = (df_full.iloc[idx + 1]["Time"] - df_full.iloc[idx - 1]["Time"]) / 2
                total_charge += scale_factor * segment_i[0] * dt_est
            group_start = i + 1
    if group_start < len(time):
        segment_t = time[group_start:]
        segment_i = current[group_start:]
        if len(segment_t) > 1:
            total_charge += scale_factor * cumulative_trapezoid(segment_i, segment_t, initial=0)[-1]
        elif len(segment_t) == 1:
            dt_est = 1e-6
            t0 = segment_t[0]
            if t0 in df_full["Time"].values:
                idx = df_full.index[df_full["Time"] == t0].tolist()[0]
                if 0 < idx < len(df_full) - 1:
                    dt_est = (df_full.iloc[idx + 1]["Time"] - df_full.iloc[idx - 1]["Time"]) / 2
            total_charge += scale_factor * segment_i[0] * dt_est
    return total_charge

# 적분 수행
p_charge = segment_and_integrate(p_current, p_time, df)
n_charge = segment_and_integrate(n_current, n_time, df)

print(f"양수 전하 값: {p_charge:.6f} nC")
print(f"음수 전하 값: {n_charge:.6f} nC")

plt.figure(figsize=(10, 5))
plt.plot(df_filtered.iloc[:, 0], df_filtered.iloc[:, 1], label="Current", color='g')
plt.xlabel("Time (s)")
#plt.ylabel("Current (μA)") ### 단위 고려 중요
#plt.title("Flat DEG Current / d=2cm")
#plt.ylim(-45, 5)
#plt.legend()
plt.grid(True)
plt.show()
# Out:
# 양수 전하 값: 21004.144120 nC
# 음수 전하 값: 0.000000 nC

# %%
# ---- 아래 셀은 offset 바꿔가며 여러 번 실행해도 누적 안됨 ----
offset_value = -1.7 ########################## MUST BE MODIFIED MANUALLY

# 딱 한 번만 실행해서 '기준'을 저장
df_filtered_base = df_filtered.copy(deep=True)  # 원본 백업
current_adj = df_filtered_base["Current"] + offset_value

# 적분 (μA -> nC)
cumulative_charge = 1e3 * cumulative_trapezoid(current_adj.to_numpy(),
                                               df_filtered_base["Time"].to_numpy(),
                                               initial=0)

# 플롯
#print(f"{np.min(cumulative_charge):.3f} nC")
print(f"{np.min(cumulative_charge):.3f}")
plt.figure(figsize=(10, 5))
#plt.ylim(-0.37,0.02)
plt.plot(df_filtered_base["Time"], cumulative_charge, label="Cumulative Charge")
#plt.xlabel("Time (s)"); plt.ylabel("Collected Charge (nC)")
#plt.title("Flat DEG Charge / d=2cm");
plt.grid(True); plt.show()


# 8. 시간-전하(Time, Charge) 데이터 저장
folder_path = os.path.dirname(file_path)
original_filename = os.path.basename(file_pㅈath)
filtered_file_name = f"Charge_{original_filename}"
filtered_file_path = os.path.join(folder_path, filtered_file_name)
charge_output_df = pd.DataFrame({"Time": df_filtered_base["Time"].to_numpy(), "Charge": cumulative_charge})
charge_output_df.to_csv(filtered_file_path, index=False, header=False)

print(f"Filtered data saved at: {filtered_file_path}")
# Out:
# 0.000
# Filtered data saved at: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\2. Normal Supercapacitor\240911_전압,전류 측정\Charge_240911_2 uA_long.csv
