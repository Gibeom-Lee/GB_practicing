# %%
import pandas as pd
import numpy as np
import os
from scipy.integrate import cumulative_trapezoid

# ==========================================
# 1. 사용자 설정 (Path 및 파라미터)
# ==========================================
folder_path = r"G:\다른 컴퓨터\KHU PC\HI Lab\0. Projects\0. On going\2. Aloe inspired DEG\1. 실험자료\5. Revision experiment\260111\Figure 1f\Current Conv 8cm_50uAV"

output_filename = "00Results_Summary.csv"

fraction_percent = 10  # baseline 추정 비율 (%)
Current_scale = 50     # μA/V 스케일링 계수

# %%
# ==========================================
# 2. 전하 적분 함수 정의
# ==========================================
def segment_and_integrate(current, time, df_full, threshold=0.01, scale_factor=1e3):
    if len(time) < 1:
        return 0.0
    total_charge = 0.0
    group_start = 0
    time_diffs = np.diff(time)
    
    for i, dt in enumerate(time_diffs):
        if dt > threshold:
            segment_t = time[group_start:i+1]
            segment_i = current[group_start:i+1]
            if len(segment_t) > 1:
                total_charge += scale_factor * cumulative_trapezoid(segment_i, segment_t, initial=0)[-1]
            elif len(segment_t) == 1:
                dt_est = 1e-6
                t0 = segment_t[0]
                if t0 in df_full["Time"].values:
                    idx = df_full.index[df_full["Time"] == t0].tolist()[0]
                    if 0 < idx < len(df_full) - 1:
                        dt_est = (df_full.iloc[idx + 1]["Time"] - df_full.iloc[idx - 1]["Time"]) / 2
                total_charge += scale_factor * segment_i[0] * dt_est
            group_start = i + 1
            
    if group_start < len(time):
        segment_t = time[group_start:]
        segment_i = current[group_start:]
        if len(segment_t) > 1:
            total_charge += scale_factor * cumulative_trapezoid(segment_i, segment_t, initial=0)[-1]
        elif len(segment_t) == 1:
            dt_est = 1e-6
            t0 = segment_t[0]
            if t0 in df_full["Time"].values:
                idx = df_full.index[df_full["Time"] == t0].tolist()[0]
                if 0 < idx < len(df_full) - 1:
                    dt_est = (df_full.iloc[idx + 1]["Time"] - df_full.iloc[idx - 1]["Time"]) / 2
            total_charge += scale_factor * segment_i[0] * dt_est
            
    return total_charge

# ==========================================
# 3. 폴더 순회 및 데이터 처리 (정렬 추가)
# ==========================================
results_list = []

# 파일 이름을 순서대로 정렬 (sorted 사용)
file_list = sorted([f for f in os.listdir(folder_path) if f.endswith('.csv') and f != output_filename])

print(f"총 {len(file_list)}개의 파일을 순서대로 처리합니다.")

for filename in file_list:
    full_path = os.path.join(folder_path, filename)
    
    try:
        df = pd.read_csv(full_path, header=None, skiprows=30)
        df.columns = ['Time', 'Current']
        df["Time"] = pd.to_numeric(df["Time"], errors='coerce')
        df["Current"] = pd.to_numeric(df["Current"], errors='coerce')
        df = df.dropna(subset=['Time', 'Current'])

        # Baseline Correction
        current_raw = df['Current'].values
        n_total = len(current_raw)
        n_fraction = int(n_total * (fraction_percent / 100))
        
        baseline_offset = np.mean(np.concatenate([current_raw[:n_fraction], current_raw[-n_fraction:]]))
        baseline_offset = 0.0 if np.isnan(baseline_offset) else baseline_offset
        
        # 보정된 전류 (스케일 적용)
        df['Cor_current'] = (df['Current'] - baseline_offset) * Current_scale
        
        # 1. 전류 최대/최소값
        max_current = df['Cor_current'].max()
        min_current = df['Cor_current'].min()
        
        # 2. 전하 적분 (양수/음수 분리)
        p_df = df[df["Cor_current"] > 0]
        n_df = df[df["Cor_current"] < 0]
        
        p_charge = segment_and_integrate(p_df["Cor_current"].values, p_df["Time"].values, df)
        n_charge = segment_and_integrate(n_df["Cor_current"].values, n_df["Time"].values, df)
        
        # 결과 정리
        results_list.append({
            "File Name": filename,
            "Max Current (uA)": max_current,
            "Min Current (uA)": min_current,
            "Max Charge (nC)": p_charge,
            "Min Charge (nC)": n_charge,
            "Offset (V)": baseline_offset
        })
        print(f"완료: {filename}")
        
    except Exception as e:
        print(f"오류 ({filename}): {e}")

# ==========================================
# 4. 결과 저장 (소수점 처리 추가)
# ==========================================
summary_df = pd.DataFrame(results_list)

# 모든 수치형 데이터를 소수점 3자리까지 반올림
summary_df = summary_df.round(3)

output_path = os.path.join(folder_path, output_filename)
summary_df.to_csv(output_path, index=False, encoding='utf-8-sig')

print("-" * 30)
print(f"모든 작업이 완료되었습니다.")
print(f"결과 파일 저장 경로: {output_path}")
print(summary_df)
# Out:
# 총 500개의 파일을 순서대로 처리합니다.
# 완료: tek0000ALL.csv
# 완료: tek0001ALL.csv
# 완료: tek0002ALL.csv
# 완료: tek0003ALL.csv
# 완료: tek0004ALL.csv
# 완료: tek0005ALL.csv
# 완료: tek0006ALL.csv
# 완료: tek0007ALL.csv
# 완료: tek0008ALL.csv
# 완료: tek0009ALL.csv
# 완료: tek0010ALL.csv
# 완료: tek0011ALL.csv
# 완료: tek0012ALL.csv
# 완료: tek0013ALL.csv
# 완료: tek0014ALL.csv
# 완료: tek0015ALL.csv
# 완료: tek0016ALL.csv
# 완료: tek0017ALL.csv
# 완료: tek0018ALL.csv
# 완료: tek0019ALL.csv
# 완료: tek0020ALL.csv
# 완료: tek0021ALL.csv
# 완료: tek0022ALL.csv
# 완료: tek0023ALL.csv
# 완료: tek0024ALL.csv
# 완료: tek0025ALL.csv
# 완료: tek0026ALL.csv
# 완료: tek0027ALL.csv
# 완료: tek0028ALL.csv
# 완료: tek0029ALL.csv
# 완료: tek0030ALL.csv
# 완료: tek0031ALL.csv
# 완료: tek0032ALL.csv
# 완료: tek0033ALL.csv
# 완료: tek0034ALL.csv
# 완료: tek0035ALL.csv
# 완료: tek0036ALL.csv
# 완료: tek0037ALL.csv
# 완료: tek0038ALL.csv
# 완료: tek0039ALL.csv
# 완료: tek0040ALL.csv
# 완료: tek0041ALL.csv
# 완료: tek0042ALL.csv
# 완료: tek0043ALL.csv
# 완료: tek0044ALL.csv
# 완료: tek0045ALL.csv
# 완료: tek0046ALL.csv
# 완료: tek0047ALL.csv
# 완료: tek0048ALL.csv
# 완료: tek0049ALL.csv
# 완료: tek0050ALL.csv
# 완료: tek0051ALL.csv
# 완료: tek0052ALL.csv
# 완료: tek0053ALL.csv
# 완료: tek0054ALL.csv
# 완료: tek0055ALL.csv
# 완료: tek0056ALL.csv
# 완료: tek0057ALL.csv
# 완료: tek0058ALL.csv
# 완료: tek0059ALL.csv
# 완료: tek0060ALL.csv
# 완료: tek0061ALL.csv
# 완료: tek0062ALL.csv
# 완료: tek0063ALL.csv
# 완료: tek0064ALL.csv
# 완료: tek0065ALL.csv
# 완료: tek0066ALL.csv
# 완료: tek0067ALL.csv
# 완료: tek0068ALL.csv
# 완료: tek0069ALL.csv
# 완료: tek0070ALL.csv
# 완료: tek0071ALL.csv
# 완료: tek0072ALL.csv
# 완료: tek0073ALL.csv
# 완료: tek0074ALL.csv
# 완료: tek0075ALL.csv
# 완료: tek0076ALL.csv
# 완료: tek0077ALL.csv
# 완료: tek0078ALL.csv
# 완료: tek0079ALL.csv
# 완료: tek0080ALL.csv
# 완료: tek0081ALL.csv
# 완료: tek0082ALL.csv
# 완료: tek0083ALL.csv
# 완료: tek0084ALL.csv
# 완료: tek0085ALL.csv
# 완료: tek0086ALL.csv
# 완료: tek0087ALL.csv
# 완료: tek0088ALL.csv
# 완료: tek0089ALL.csv
# 완료: tek0090ALL.csv
# 완료: tek0091ALL.csv
# 완료: tek0092ALL.csv
# 완료: tek0093ALL.csv
# 완료: tek0094ALL.csv
# 완료: tek0095ALL.csv
# 완료: tek0096ALL.csv
# 완료: tek0097ALL.csv
# 완료: tek0098ALL.csv
# 완료: tek0099ALL.csv
# 완료: tek0100ALL.csv
# 완료: tek0101ALL.csv
# 완료: tek0102ALL.csv
# 완료: tek0103ALL.csv
# 완료: tek0104ALL.csv
# 완료: tek0105ALL.csv
# 완료: tek0106ALL.csv
# 완료: tek0107ALL.csv
# 완료: tek0108ALL.csv
# 완료: tek0109ALL.csv
# 완료: tek0110ALL.csv
# 완료: tek0111ALL.csv
# 완료: tek0112ALL.csv
# 완료: tek0113ALL.csv
# 완료: tek0114ALL.csv
# 완료: tek0115ALL.csv
# 완료: tek0116ALL.csv
# 완료: tek0117ALL.csv
# 완료: tek0118ALL.csv
# 완료: tek0119ALL.csv
# 완료: tek0120ALL.csv
# 완료: tek0121ALL.csv
# 완료: tek0122ALL.csv
# 완료: tek0123ALL.csv
# 완료: tek0124ALL.csv
# 완료: tek0125ALL.csv
# 완료: tek0126ALL.csv
# 완료: tek0127ALL.csv
# 완료: tek0128ALL.csv
# 완료: tek0129ALL.csv
# 완료: tek0130ALL.csv
# 완료: tek0131ALL.csv
# 완료: tek0132ALL.csv
# 완료: tek0133ALL.csv
# 완료: tek0134ALL.csv
# 완료: tek0135ALL.csv
# 완료: tek0136ALL.csv
# 완료: tek0137ALL.csv
# 완료: tek0138ALL.csv
# 완료: tek0139ALL.csv
# 완료: tek0140ALL.csv
# 완료: tek0141ALL.csv
# 완료: tek0142ALL.csv
# 완료: tek0143ALL.csv
# 완료: tek0144ALL.csv
# 완료: tek0145ALL.csv
# 완료: tek0146ALL.csv
# 완료: tek0147ALL.csv
# 완료: tek0148ALL.csv
# 완료: tek0149ALL.csv
# 완료: tek0150ALL.csv
# 완료: tek0151ALL.csv
# 완료: tek0152ALL.csv
# 완료: tek0153ALL.csv
# 완료: tek0154ALL.csv
# 완료: tek0155ALL.csv
# 완료: tek0156ALL.csv
# 완료: tek0157ALL.csv
# 완료: tek0158ALL.csv
# 완료: tek0159ALL.csv
# 완료: tek0160ALL.csv
# 완료: tek0161ALL.csv
# 완료: tek0162ALL.csv
# 완료: tek0163ALL.csv
# 완료: tek0164ALL.csv
# 완료: tek0165ALL.csv
# 완료: tek0166ALL.csv
# 완료: tek0167ALL.csv
# 완료: tek0168ALL.csv
# 완료: tek0169ALL.csv
# 완료: tek0170ALL.csv
# 완료: tek0171ALL.csv
# 완료: tek0172ALL.csv
# 완료: tek0173ALL.csv
# 완료: tek0174ALL.csv
# 완료: tek0175ALL.csv
# 완료: tek0176ALL.csv
# 완료: tek0177ALL.csv
# 완료: tek0178ALL.csv
# 완료: tek0179ALL.csv
# 완료: tek0180ALL.csv
# 완료: tek0181ALL.csv
# 완료: tek0182ALL.csv
# 완료: tek0183ALL.csv
# 완료: tek0184ALL.csv
# 완료: tek0185ALL.csv
# 완료: tek0186ALL.csv
# 완료: tek0187ALL.csv
# 완료: tek0188ALL.csv
# 완료: tek0189ALL.csv
# 완료: tek0190ALL.csv
# 완료: tek0191ALL.csv
# 완료: tek0192ALL.csv
# 완료: tek0193ALL.csv
# 완료: tek0194ALL.csv
# 완료: tek0195ALL.csv
# 완료: tek0196ALL.csv
# 완료: tek0197ALL.csv
# 완료: tek0198ALL.csv
# 완료: tek0199ALL.csv
# 완료: tek0200ALL.csv
# 완료: tek0201ALL.csv
# 완료: tek0202ALL.csv
# 완료: tek0203ALL.csv
# 완료: tek0204ALL.csv
# 완료: tek0205ALL.csv
# 완료: tek0206ALL.csv
# 완료: tek0207ALL.csv
# 완료: tek0208ALL.csv
# 완료: tek0209ALL.csv
# 완료: tek0210ALL.csv
# 완료: tek0211ALL.csv
# 완료: tek0212ALL.csv
# 완료: tek0213ALL.csv
# 완료: tek0214ALL.csv
# 완료: tek0215ALL.csv
# 완료: tek0216ALL.csv
# 완료: tek0217ALL.csv
# 완료: tek0218ALL.csv
# 완료: tek0219ALL.csv
# 완료: tek0220ALL.csv
# 완료: tek0221ALL.csv
# 완료: tek0222ALL.csv
# 완료: tek0223ALL.csv
# 완료: tek0224ALL.csv
# 완료: tek0225ALL.csv
# 완료: tek0226ALL.csv
# 완료: tek0227ALL.csv
# 완료: tek0228ALL.csv
# 완료: tek0229ALL.csv
# 완료: tek0230ALL.csv
# 완료: tek0231ALL.csv
# 완료: tek0232ALL.csv
# 완료: tek0233ALL.csv
# 완료: tek0234ALL.csv
# 완료: tek0235ALL.csv
# 완료: tek0236ALL.csv
# 완료: tek0237ALL.csv
# 완료: tek0238ALL.csv
# 완료: tek0239ALL.csv
# 완료: tek0240ALL.csv
# 완료: tek0241ALL.csv
# 완료: tek0242ALL.csv
# 완료: tek0243ALL.csv
# 완료: tek0244ALL.csv
# 완료: tek0245ALL.csv
# 완료: tek0246ALL.csv
# 완료: tek0247ALL.csv
# 완료: tek0248ALL.csv
# 완료: tek0249ALL.csv
# 완료: tek0250ALL.csv
# 완료: tek0251ALL.csv
# 완료: tek0252ALL.csv
# 완료: tek0253ALL.csv
# 완료: tek0254ALL.csv
# 완료: tek0255ALL.csv
# 완료: tek0256ALL.csv
# 완료: tek0257ALL.csv
# 완료: tek0258ALL.csv
# 완료: tek0259ALL.csv
# 완료: tek0260ALL.csv
# 완료: tek0261ALL.csv
# 완료: tek0262ALL.csv
# 완료: tek0263ALL.csv
# 완료: tek0264ALL.csv
# 완료: tek0265ALL.csv
# 완료: tek0266ALL.csv
# 완료: tek0267ALL.csv
# 완료: tek0268ALL.csv
# 완료: tek0269ALL.csv
# 완료: tek0270ALL.csv
# 완료: tek0271ALL.csv
# 완료: tek0272ALL.csv
# 완료: tek0273ALL.csv
# 완료: tek0274ALL.csv
# 완료: tek0275ALL.csv
# 완료: tek0276ALL.csv
# 완료: tek0277ALL.csv
# 완료: tek0278ALL.csv
# 완료: tek0279ALL.csv
# 완료: tek0280ALL.csv
# 완료: tek0281ALL.csv
# 완료: tek0282ALL.csv
# 완료: tek0283ALL.csv
# 완료: tek0284ALL.csv
# 완료: tek0285ALL.csv
# 완료: tek0286ALL.csv
# 완료: tek0287ALL.csv
# 완료: tek0288ALL.csv
# 완료: tek0289ALL.csv
# 완료: tek0290ALL.csv
# 완료: tek0291ALL.csv
# 완료: tek0292ALL.csv
# 완료: tek0293ALL.csv
# 완료: tek0294ALL.csv
# 완료: tek0295ALL.csv
# 완료: tek0296ALL.csv
# 완료: tek0297ALL.csv
# 완료: tek0298ALL.csv
# 완료: tek0299ALL.csv
# 완료: tek0300ALL.csv
# 완료: tek0301ALL.csv
# 완료: tek0302ALL.csv
# 완료: tek0303ALL.csv
# 완료: tek0304ALL.csv
# 완료: tek0305ALL.csv
# 완료: tek0306ALL.csv
# 완료: tek0307ALL.csv
# 완료: tek0308ALL.csv
# 완료: tek0309ALL.csv
# 완료: tek0310ALL.csv
# 완료: tek0311ALL.csv
# 완료: tek0312ALL.csv
# 완료: tek0313ALL.csv
# 완료: tek0314ALL.csv
# 완료: tek0315ALL.csv
# 완료: tek0316ALL.csv
# 완료: tek0317ALL.csv
# 완료: tek0318ALL.csv
# 완료: tek0319ALL.csv
# 완료: tek0320ALL.csv
# 완료: tek0321ALL.csv
# 완료: tek0322ALL.csv
# 완료: tek0323ALL.csv
# 완료: tek0324ALL.csv
# 완료: tek0325ALL.csv
# 완료: tek0326ALL.csv
# 완료: tek0327ALL.csv
# 완료: tek0328ALL.csv
# 완료: tek0329ALL.csv
# 완료: tek0330ALL.csv
# 완료: tek0331ALL.csv
# 완료: tek0332ALL.csv
# 완료: tek0333ALL.csv
# 완료: tek0334ALL.csv
# 완료: tek0335ALL.csv
# 완료: tek0336ALL.csv
# 완료: tek0337ALL.csv
# 완료: tek0338ALL.csv
# 완료: tek0339ALL.csv
# 완료: tek0340ALL.csv
# 완료: tek0341ALL.csv
# 완료: tek0342ALL.csv
# 완료: tek0343ALL.csv
# 완료: tek0344ALL.csv
# 완료: tek0345ALL.csv
# 완료: tek0346ALL.csv
# 완료: tek0347ALL.csv
# 완료: tek0348ALL.csv
# 완료: tek0349ALL.csv
# 완료: tek0350ALL.csv
# 완료: tek0351ALL.csv
# 완료: tek0352ALL.csv
# 완료: tek0353ALL.csv
# 완료: tek0354ALL.csv
# 완료: tek0355ALL.csv
# 완료: tek0356ALL.csv
# 완료: tek0357ALL.csv
# 완료: tek0358ALL.csv
# 완료: tek0359ALL.csv
# 완료: tek0360ALL.csv
# 완료: tek0361ALL.csv
# 완료: tek0362ALL.csv
# 완료: tek0363ALL.csv
# 완료: tek0364ALL.csv
# 완료: tek0365ALL.csv
# 완료: tek0366ALL.csv
# 완료: tek0367ALL.csv
# 완료: tek0368ALL.csv
# 완료: tek0369ALL.csv
# 완료: tek0370ALL.csv
# 완료: tek0371ALL.csv
# 완료: tek0372ALL.csv
# 완료: tek0373ALL.csv
# 완료: tek0374ALL.csv
# 완료: tek0375ALL.csv
# 완료: tek0376ALL.csv
# 완료: tek0377ALL.csv
# 완료: tek0378ALL.csv
# 완료: tek0379ALL.csv
# 완료: tek0380ALL.csv
# 완료: tek0381ALL.csv
# 완료: tek0382ALL.csv
# 완료: tek0383ALL.csv
# 완료: tek0384ALL.csv
# 완료: tek0385ALL.csv
# 완료: tek0386ALL.csv
# 완료: tek0387ALL.csv
# 완료: tek0388ALL.csv
# 완료: tek0389ALL.csv
# 완료: tek0390ALL.csv
# 완료: tek0391ALL.csv
# 완료: tek0392ALL.csv
# 완료: tek0393ALL.csv
# 완료: tek0394ALL.csv
# 완료: tek0395ALL.csv
# 완료: tek0396ALL.csv
# 완료: tek0397ALL.csv
# 완료: tek0398ALL.csv
# 완료: tek0399ALL.csv
# 완료: tek0400ALL.csv
# 완료: tek0401ALL.csv
# 완료: tek0402ALL.csv
# 완료: tek0403ALL.csv
# 완료: tek0404ALL.csv
# 완료: tek0405ALL.csv
# 완료: tek0406ALL.csv
# 완료: tek0407ALL.csv
# 완료: tek0408ALL.csv
# 완료: tek0409ALL.csv
# 완료: tek0410ALL.csv
# 완료: tek0411ALL.csv
# 완료: tek0412ALL.csv
# 완료: tek0413ALL.csv
# 완료: tek0414ALL.csv
# 완료: tek0415ALL.csv
# 완료: tek0416ALL.csv
# 완료: tek0417ALL.csv
# 완료: tek0418ALL.csv
# 완료: tek0419ALL.csv
# 완료: tek0420ALL.csv
# 완료: tek0421ALL.csv
# 완료: tek0422ALL.csv
# 완료: tek0423ALL.csv
# 완료: tek0424ALL.csv
# 완료: tek0425ALL.csv
# 완료: tek0426ALL.csv
# 완료: tek0427ALL.csv
# 완료: tek0428ALL.csv
# 완료: tek0429ALL.csv
# 완료: tek0430ALL.csv
# 완료: tek0431ALL.csv
# 완료: tek0432ALL.csv
# 완료: tek0433ALL.csv
# 완료: tek0434ALL.csv
# 완료: tek0435ALL.csv
# 완료: tek0436ALL.csv
# 완료: tek0437ALL.csv
# 완료: tek0438ALL.csv
# 완료: tek0439ALL.csv
# 완료: tek0440ALL.csv
# 완료: tek0441ALL.csv
# 완료: tek0442ALL.csv
# 완료: tek0443ALL.csv
# 완료: tek0444ALL.csv
# 완료: tek0445ALL.csv
# 완료: tek0446ALL.csv
# 완료: tek0447ALL.csv
# 완료: tek0448ALL.csv
# 완료: tek0449ALL.csv
# 완료: tek0450ALL.csv
# 완료: tek0451ALL.csv
# 완료: tek0452ALL.csv
# 완료: tek0453ALL.csv
# 완료: tek0454ALL.csv
# 완료: tek0455ALL.csv
# 완료: tek0456ALL.csv
# 완료: tek0457ALL.csv
# 완료: tek0458ALL.csv
# 완료: tek0459ALL.csv
# 완료: tek0460ALL.csv
# 완료: tek0461ALL.csv
# 완료: tek0462ALL.csv
# 완료: tek0463ALL.csv
# 완료: tek0464ALL.csv
# 완료: tek0465ALL.csv
# 완료: tek0466ALL.csv
# 완료: tek0467ALL.csv
# 완료: tek0468ALL.csv
# 완료: tek0469ALL.csv
# 완료: tek0470ALL.csv
# 완료: tek0471ALL.csv
# 완료: tek0472ALL.csv
# 완료: tek0473ALL.csv
# 완료: tek0474ALL.csv
# 완료: tek0475ALL.csv
# 완료: tek0476ALL.csv
# 완료: tek0477ALL.csv
# 완료: tek0478ALL.csv
# 완료: tek0479ALL.csv
# 완료: tek0480ALL.csv
# 완료: tek0481ALL.csv
# 완료: tek0482ALL.csv
# 완료: tek0483ALL.csv
# 완료: tek0484ALL.csv
# 완료: tek0485ALL.csv
# 완료: tek0486ALL.csv
# 완료: tek0487ALL.csv
# 완료: tek0488ALL.csv
# 완료: tek0489ALL.csv
# 완료: tek0490ALL.csv
# 완료: tek0491ALL.csv
# 완료: tek0492ALL.csv
# 완료: tek0493ALL.csv
# 완료: tek0494ALL.csv
# 완료: tek0495ALL.csv
# 완료: tek0496ALL.csv
# 완료: tek0497ALL.csv
# 완료: tek0498ALL.csv
# 완료: tek0499ALL.csv
# ------------------------------
# 모든 작업이 완료되었습니다.
# 결과 파일 저장 경로: G:\다른 컴퓨터\KHU PC\HI Lab\0. Projects\0. On going\2. Aloe inspired DEG\1. 실험자료\5. Revision experiment\260111\Figure 1f\Current Conv 8cm_50uAV\00Results_Summary.csv
#           File Name  Max Current (uA)  Min Current (uA)  Max Charge (nC)  \
# 0    tek0000ALL.csv             1.193           -18.479            0.112
# 1    tek0001ALL.csv             0.986            -6.288            0.111
# 2    tek0002ALL.csv             0.831            -7.607            0.105
# 3    tek0003ALL.csv             0.870           -11.286            0.105
# 4    tek0004ALL.csv             1.385           -18.560            0.112
# ..              ...               ...               ...              ...
# 495  tek0495ALL.csv             1.268           -30.872            0.099
# 496  tek0496ALL.csv             0.784           -16.688            0.095
# 497  tek0497ALL.csv             0.966           -23.581            0.091
# 498  tek0498ALL.csv             0.607           -15.108            0.083
# 499  tek0499ALL.csv             0.830            -9.283            0.103
#
#      Min Charge (nC)  Offset (V)
# 0             -0.198       0.012
# 1             -0.127       0.012
# 2             -0.141       0.013
# 3             -0.213       0.012
# 4             -0.196       0.011
# ..               ...         ...
# 495           -0.449       0.013
# 496           -0.209       0.014
# 497           -0.252       0.013
# 498           -0.208       0.013
# 499           -0.156       0.014
#
# [500 rows x 6 columns]
