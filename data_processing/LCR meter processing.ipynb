# %%
import os
import glob
import pandas as pd

# ====== 1. 로컬 폴더 경로 입력 ======
folder_path = r"C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일"

# %%
# ====== 2. 새로 넣을 Hz 데이터 (201개) ======
new_hz_column = [
    20, 21.1851, 22.4404, 23.77, 25.1785, 26.6704, 28.2508, 29.9247, 31.6979, 33.5761,
    35.5656, 37.673, 39.9052, 42.2698, 44.7744, 47.4275, 50.2377, 53.2145, 56.3677,
    59.7077, 63.2456, 66.9931, 70.9627, 75.1675, 79.6214, 84.3393, 89.3367, 94.6303,
    100.237, 106.177, 112.468, 119.132, 126.191, 133.669, 141.589, 149.979, 158.866,
    168.279, 178.25, 188.812, 200, 211.851, 224.404, 237.7, 251.785, 266.704, 282.508,
    299.247, 316.979, 335.761, 355.656, 376.73, 399.052, 422.698, 447.744, 474.275,
    502.377, 532.145, 563.677, 597.077, 632.456, 669.931, 709.627, 751.675, 796.214,
    843.393, 893.367, 946.303, 1002.37, 1061.77, 1124.68, 1191.32, 1261.91, 1336.69,
    1415.89, 1499.79, 1588.66, 1682.79, 1782.5, 1888.12, 2000, 2118.51, 2244.04, 2377,
    2517.85, 2667.04, 2825.08, 2992.47, 3169.79, 3357.61, 3556.56, 3767.3, 3990.52,
    4226.98, 4477.44, 4742.75, 5023.77, 5321.45, 5636.77, 5970.77, 6324.56, 6699.31,
    7096.27, 7516.75, 7962.14, 8433.93, 8933.67, 9463.03, 10023.7, 10617.7, 11246.8,
    11913.2, 12619.1, 13366.9, 14158.9, 14997.9, 15886.6, 16827.9, 17825, 18881.2,
    20000, 21185.1, 22440.4, 23770, 25178.5, 26670.4, 28250.8, 29924.7, 31697.9,
    33576.1, 35565.6, 37673, 39905.2, 42269.8, 44774.4, 47427.5, 50237.7, 53214.5,
    56367.7, 59707.7, 63245.6, 66993.1, 70962.7, 75167.5, 79621.4, 84339.3, 89336.7,
    94630.3, 100237, 106177, 112468, 119132, 126191, 133669, 141589, 149979, 158866,
    168279, 178250, 188812, 200000, 211851, 224404, 237700, 251785, 266704, 282508,
    299247, 316979, 335761, 355656, 376730, 399052, 422698, 447744, 474275, 502377,
    532145, 563677, 597077, 632456, 669931, 709627, 751675, 796214, 843393, 893367,
    946303, 1002370, 1061770, 1124680, 1191320, 1261910, 1336690, 1415890, 1499790,
    1588660, 1682790, 1782500, 1888120, 2000000
]

# ====== 3. CSV 파일 처리 ======
csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

for file in csv_files:
    print(f"Processing: {file}")
    
    # 원본 읽기 (4열이라고 가정)
    try:
        df_original = pd.read_csv(file, header=None)
        
        # 행 개수 검증
        if len(df_original) != len(new_hz_column):
            print(f"Skipping {file}: 행 개수가 {len(df_original)}개입니다. (201개 필요)")
            continue

        first_col_numeric = pd.to_numeric(df_original.iloc[:, 0], errors="coerce")
        if first_col_numeric.notna().all() and first_col_numeric.iloc[0] == 20 and first_col_numeric.iloc[-1] == 2000000:
            print(f"Skipping {file}: already contains Hz column.")
            continue

        # [새 Hz열, 기존 1열, 기존 2열] 순서로 새 데이터프레임 생성
        # iloc[:, 0]은 첫번째 열, iloc[:, 1]은 두번째 열을 의미함
        df_new = pd.DataFrame({
            'A': new_hz_column,
            'B': df_original.iloc[:, 0].values,
            'C': df_original.iloc[:, 1].values
        })

        # 결과 저장 (헤더 없이 저장하려면 header=False)
        df_new.to_csv(file, index=False, header=False)
        
    except Exception as e:
        print(f"Error processing {file}: {e}")

print("모든 작업이 완료되었습니다.")
# Out:
# Processing: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일\10x10_CR_CpRp (2).csv
# Processing: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일\10x10_CR_CpRp (3).csv
# Processing: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일\10x10_CR_CpRp.csv
# Processing: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일\10x10_CR_CsRs (2).csv
# Processing: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일\10x10_CR_CsRs (3).csv
# Processing: C:\Users\user\Desktop\Gibeom\1. HI Lab\0. Projects\0. On going\1. ionic DC-TENG\0. 실험자료\8. Gibeom touch\260330_LCR미터 면적별\csv파일\10x10_CR_CsRs.csv
# ...
